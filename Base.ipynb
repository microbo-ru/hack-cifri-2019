# %%
import plotly
plotly.__version__
# Out:
# '3.10.0'

# %%
# import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import numpy as np

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#!wget https://data.gov.ru/opendata/7705598840-sanitationactivities/data-20190606T1257-structure-20190606T1257.csv
# !wget https://data.gov.ru/opendata/7705598840-sanitationactivities/structure-20190606T1257.csv
# !ls
# Out:
# --2019-06-08 14:51:50--  https://data.gov.ru/opendata/7705598840-sanitationactivities/structure-20190606T1257.csv
# Selvitet"a"an osoitetta data.gov.ru (data.gov.ru)... 46.61.230.118
# Yhdistet"a"an palvelimeen data.gov.ru (data.gov.ru)|46.61.230.118|:443... yhdistetty.
# HTTP-pyynt"o l"ahetetty, odotetaan vastausta... 200 OK
# Pituus: 441 [text/plain]
# Tallennetaan kohteeseen <<structure-20190606T1257.csv>>
#
# structure-20190606T 100%[===================>]     441  --.-KB/s    in 0s
#
# 2019-06-08 14:51:51 (12.4 MB/s) - <<structure-20190606T1257.csv>> tallennettu [441/441]
#
# Base.ipynb
# data-20190606T1257-structure-20190606T1257.csv
# structure-20190606T1257.csv
# world-bank-eda-interactive-dashboard-python.ipynb

# %%
#https://data.gov.ru/opendata/7705598840-sanitationactivities

# %%
#iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])

# %%
import pandas as pd
df = pd.read_csv('data-20190606T1257-structure-20190606T1257.csv')
df_s = pd.read_csv('structure-20190606T1257.csv')

# %%
print(df_s)
# Out:
#    №                                  Наименование поля  Описание  \
# 0  1  Наименование органа \r\nисполнительной власти ...       NaN
# 1  2                                 план за 2018 г, га       NaN
# 2  3                               факт за 2018 год, га       NaN
# 3  4                           план за 2018 год, м. куб       NaN
# 4  5                            факт за 2018 год, м.куб       NaN
#
#   Формат значения поля
# 0           xsd:string
# 1          xsd:decimal
# 2          xsd:decimal
# 3          xsd:decimal
# 4          xsd:decimal

# %%
print(df)
# Out:
#    Наименование органа \r\nисполнительной власти \r\nсубъекта РФ  \
# 0                                 Всего по Рослесхозу
# 1                       Центральный Федеральный округ
# 2                                Белгородская область
# 3                                    Брянская область
# 4                                Владимирская область
# 5                                 Воронежская область
# 6                                  Ивановская область
# 7                                   Калужская область
# 8                                 Костромская область
# 9                                     Курская область
# 10                                   Липецкая область
# 11                                 Московская область
# 12                                  Орловская область
# 13                                  Рязанская область
# 14                                 Смоленская область
# 15                                 Тамбовская область
# 16                                   Тверская область
# 17                                   Тульская область
# 18                                Ярославская область
# 19                  Северо-Западный Федеральный округ
# 20                                 Республика Карелия
# 21                                    Республика Коми
# 22                              Архангельская область
# 23                                Вологодская область
# 24                            Калининградская область
# 25                              Ленинградская область
# 26                                 Мурманская область
# 27                               Новгородская область
# 28                                  Псковская область
# 29                            Южный Федеральный округ
# ..                                                ...
# 60                        Уральский Федеральный округ
# 61                                 Курганская область
# 62                               Свердловская область
# 63                                  Тюменская область
# 64                                Челябинская область
# 65           Ханты-Мансийский автономный округ - Югра
# 66                    Ямало-Ненецкий автономный округ
# 67                        Сибирский Федеральный округ
# 68                                   Республика Алтай
# 69                                 Республика Бурятия
# 70                                    Республика Тыва
# 71                                 Республика Хакасия
# 72                                     Алтайский край
# 73                                 Забайкальский край
# 74                                  Красноярский край
# 75                                  Иркутская область
# 76                                Кемеровская область
# 77                              Новосибирская область
# 78                                     Омская область
# 79                                    Томская область
# 80                  Дальневосточный Федеральный округ
# 81                           Республика Саха (Якутия)
# 82                                    Камчатский край
# 83                                    Приморский край
# 84                                   Хабаровский край
# 85                                   Амурская область
# 86                                Магаданская область
# 87                                Сахалинская область
# 88                       Еврейская автономная область
# 89                         Чукотский автономный округ
#
#     план за 2018 г, га  факт за 2018 год, га  план за 2018 год, м. куб  \
# 0           323622.503           260242.2408              2.467507e+07
# 1            50087.420            52473.6710              3.985756e+06
# 2             1877.380             1877.3800              4.286741e+04
# 3             5422.900             5451.5000              3.056430e+05
# 4             5058.800             3498.7700              2.169330e+05
# 5             3000.000             2984.5400              1.205800e+05
# 6             2529.000              554.8200              1.380000e+05
# 7             2855.000             1450.7000              2.108156e+05
# 8              221.900              348.7000              2.159940e+04
# 9              529.700              547.4000              2.408500e+04
# 10            2201.740             2201.7400              1.798090e+05
# 11            6500.200             8535.3400              8.707338e+05
# 12              79.600              127.7000              2.664100e+03
# 13            3614.000             3732.4000              1.366430e+05
# 14            1623.500              636.8700              2.402830e+05
# 15            5945.800             5904.8000              2.857600e+05
# 16            7000.000            13546.1110              1.050000e+06
# 17            1005.400              599.2000              6.340000e+04
# 18             622.500              475.7000              7.594000e+04
# 19           13851.710            10506.1300              1.662516e+06
# 20             804.680              728.2400              1.059024e+05
# 21             287.700              545.0000              4.813600e+04
# 22            1533.630              274.5000              1.784604e+05
# 23            3304.000             3304.0000              5.076721e+05
# 24            3192.100             1094.0000              2.425000e+05
# 25            3474.000             3493.8000              5.244420e+05
# 26              71.000               21.1900              2.628000e+03
# 27             867.600              735.5600                       NaN
# 28             317.000              309.8400              5.277530e+04
# 29           13742.773             7589.5830              2.766949e+05
# ..                 ...                   ...                       ...
# 60           34247.900            12791.4833              1.889224e+06
# 61           14127.000             3005.2000              8.262000e+05
# 62            6746.900             5362.0000              6.682370e+05
# 63            1151.300              635.1000              9.056600e+04
# 64           11900.000             2814.2000              2.829120e+05
# 65             322.700              974.9833              2.130900e+04
# 66                 NaN                   NaN                       NaN
# 67          123267.300           102006.9000              1.291810e+07
# 68            4225.000              468.5500              1.669217e+05
# 69           11874.800             5325.8500              5.935856e+05
# 70            1607.000             1607.0000                       NaN
# 71            1014.400             1030.5000              8.499750e+04
# 72            5492.000             1691.9000              2.340380e+05
# 73           13140.000             8020.4450              7.913440e+05
# 74           37284.000            37221.8100              6.580625e+06
# 75           26026.100            28192.4900              3.595238e+06
# 76             523.800              497.3000              4.683800e+04
# 77            4385.200             2068.6000              1.702610e+05
# 78            7220.000             6228.6000              6.542523e+05
# 79           10475.000             9653.8100                       NaN
# 80            8636.500             8057.8000              7.240241e+05
# 81             107.300              107.3000              5.043100e+03
# 82             250.000              167.3600                       NaN
# 83            1514.000              975.3000              7.526200e+04
# 84            3500.000             4395.8000              4.106400e+05
# 85            1323.000              952.0000              8.752500e+04
# 86              95.000               54.9700              3.800000e+03
# 87             796.000              308.1200              7.656000e+04
# 88             506.200              369.9000              5.574400e+04
# 89             545.000              727.0000              9.450000e+03
#
#     факт за 2018 год, м.куб
# 0               25903795.34
# 1                4756105.30
# 2                  49928.51
# 3                 323304.41
# 4                 154591.00
# 5                 130820.00
# 6                  28933.00
# 7                 120785.20
# 8                  26611.32
# 9                  22644.00
# 10                179809.00
# 11               1256883.70
# 12                  3299.00
# 13                146759.00
# 14                 84333.00
# 15                284322.00
# 16               1891887.06
# 17                 37412.00
# 18                 13783.10
# 19               1552540.40
# 20                123753.30
# 21                110818.10
# 22                 25019.20
# 23                506318.20
# 24                 68700.00
# 25                642849.00
# 26                   506.00
# 27                 50656.60
# 28                 23920.00
# 29                186744.59
# ..                      ...
# 60                949494.50
# 61                145527.00
# 62                460226.00
# 63                 45108.00
# 64                191553.50
# 65                107080.00
# 66                      NaN
# 67              14032308.08
# 68                 25730.00
# 69                436358.70
# 70                      NaN
# 71                 83745.70
# 72                 64520.40
# 73                525855.18
# 74               6098197.70
# 75               4384876.40
# 76                 49315.00
# 77                105888.00
# 78                715147.00
# 79               1542674.00
# 80                872135.10
# 81                  5043.10
# 82                  7659.00
# 83                 50111.00
# 84                671894.50
# 85                 54100.00
# 86                  2984.00
# 87                 27583.00
# 88                 43663.00
# 89                  9097.50
#
# [90 rows x 5 columns]

# %%
#import cufflinks as cf

# %%
#iplot(cf.datagen.lines().iplot(asFigure=True,
#                              kind='scatter',xTitle='Dates',yTitle='Returns',title='Returns'))

# %%
#print(cf.datagen.lines())
#plot([go.Scatter(x=[1, 2, 3], y=[3, 1, 6])])

# %%
data = [go.Bar(
            x=df.iloc[1:,0],
            y=df.iloc[1:,1]
    )]

iplot(data, filename='basic-bar')
# Out:
# <div>
#
#
#             <div id="ba794bf2-b973-48d4-8e61-e9b1b5426c7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ba794bf2-b973-48d4-8e61-e9b1b5426c7d")) {
#                     Plotly.newPlot(
#                         'ba794bf2-b973-48d4-8e61-e9b1b5426c7d',
#                         [{"type": "bar", "uid": "e806d4d4-865b-4b49-972a-7f6df10df51d", "x": ["\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u0424\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u043e\u043a\u0440\u0443\u0433", "\u0411\u0435\u043b\u0433\u043e\u0440\u043e\u0434\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0411\u0440\u044f\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0412\u043b\u0430\u0434\u0438\u043c\u0438\u0440\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0412\u043e\u0440\u043e\u043d\u0435\u0436\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0418\u0432\u0430\u043d\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041a\u0430\u043b\u0443\u0436\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041a\u043e\u0441\u0442\u0440\u043e\u043c\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041a\u0443\u0440\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041b\u0438\u043f\u0435\u0446\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041c\u043e\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041e\u0440\u043b\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0420\u044f\u0437\u0430\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0421\u043c\u043e\u043b\u0435\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0422\u0430\u043c\u0431\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0422\u0432\u0435\u0440\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0422\u0443\u043b\u044c\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u042f\u0440\u043e\u0441\u043b\u0430\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0421\u0435\u0432\u0435\u0440\u043e-\u0417\u0430\u043f\u0430\u0434\u043d\u044b\u0439 \u0424\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u043e\u043a\u0440\u0443\u0433", "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u041a\u0430\u0440\u0435\u043b\u0438\u044f", "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u041a\u043e\u043c\u0438", "\u0410\u0440\u0445\u0430\u043d\u0433\u0435\u043b\u044c\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0412\u043e\u043b\u043e\u0433\u043e\u0434\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041a\u0430\u043b\u0438\u043d\u0438\u043d\u0433\u0440\u0430\u0434\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041b\u0435\u043d\u0438\u043d\u0433\u0440\u0430\u0434\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041c\u0443\u0440\u043c\u0430\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041d\u043e\u0432\u0433\u043e\u0440\u043e\u0434\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u041f\u0441\u043a\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u042e\u0436\u043d\u044b\u0439 \u0424\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d\u044b\u0439 \u043e\u043a\u0440\u0443\u0433", "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u0410\u0434\u044b\u0433\u0435\u044f", "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u041a\u0430\u043b\u043c\u044b\u043a\u0438\u044f", "\u0420\u0435\u0441\u043f\u0443\u0431\u043b\u0438\u043a\u0430 \u041a\u0440\u044b\u043c", "\u041a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440\u0441\u043a\u0438\u0439 \u043a\u0440\u0430\u0439", "\u0410\u0441\u0442\u0440\u0430\u0445\u0430\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c", "\u0420\u043e\u0441\u0442\u043e\u0432\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u04 ...
